# %%
path = "C:/Users/SDS/Downloads/text.txt"

from os.path import *
print(abspath("text.txt"))
# Out:
# C:\Users\SDS\Downloads\text.txt

# %%
open(path).readline()
# Out:
# '{"h":"1KW4Zp8","g":"1M91fCv","l":"americanenglish","hh":"1.usa.gov","u":"https://share.america.gov/everyday-conversations-writing-college-essay/","r":"http://m.facebook.com/","a":"Mozilla/5.0 (Linux; U; Android 4.3; vi-vn; SHV-E210K Build/JSS15J) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30 [FB_IAB/FB4A;FBAV/53.0.0.29.18;]","i":"","t":1446872374,"k":"","nk":0,"hc":1446564568,"_id":"9f7472aa-05bd-15d1-bb10-17c839600b9f","al":"vi-VN, en-US","c":"VN","tz":"Asia/Phnom_Penh","gr":"44","cy":"Hanoi","ll":[21.0333,105.85]}\n'

# %%
path = "C:/Users/SDS/Downloads/text.txt"

# %%
open(path).readline()
# Out:
# '{"h":"1KW4Zp8","g":"1M91fCv","l":"americanenglish","hh":"1.usa.gov","u":"https://share.america.gov/everyday-conversations-writing-college-essay/","r":"http://m.facebook.com/","a":"Mozilla/5.0 (Linux; U; Android 4.3; vi-vn; SHV-E210K Build/JSS15J) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30 [FB_IAB/FB4A;FBAV/53.0.0.29.18;]","i":"","t":1446872374,"k":"","nk":0,"hc":1446564568,"_id":"9f7472aa-05bd-15d1-bb10-17c839600b9f","al":"vi-VN, en-US","c":"VN","tz":"Asia/Phnom_Penh","gr":"44","cy":"Hanoi","ll":[21.0333,105.85]}\n'

# %%
path = "/Users/JYP/text333333.txt"
open(path).readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b3f8a177617a> in <module>()
#       1 path = "/Users/JYP/text333333.txt"
# ----> 2 open(path).readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/JYP/text333333.txt'

# %%
path = "/Users/JYP/text3.txt"
open(path).readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-84ab9e03fc59> in <module>()
#       1 path = "/Users/JYP/text3.txt"
# ----> 2 open(path).readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/JYP/text3.txt'

# %%
path = "/Users/JYP/text.txt"
open(path).readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-e9f4e37e46ad> in <module>()
#       1 path = "/Users/JYP/text.txt"
# ----> 2 open(path).readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/JYP/text.txt'

# %%
path = "/Users/JYP/text.txt"
open(path).readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-e9f4e37e46ad> in <module>()
#       1 path = "/Users/JYP/text.txt"
# ----> 2 open(path).readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/JYP/text.txt'

# %%
path = "/Users/JYP/text.txt"
open(path).readline()
recods = [json.loads(line) for line in open(path)]
print (recods[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-43a66f19cbf8> in <module>()
#       1 path = "/Users/JYP/text.txt"
# ----> 2 open(path).readline()
#       3 recods = [json.loads(line) for line in open(path)]
#       4 print (recods[0])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/JYP/text.txt'

# %%
path = "C:/Users/SDS/Downloads/text.txt"
recods = [json.loads(line) for line in open(path)]
recods[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-603651389235> in <module>()
#       1 path = "C:/Users/SDS/Downloads/text.txt"
# ----> 2 recods = [json.loads(line) for line in open(path)]
#       3 recods[0]
#
# <ipython-input-10-603651389235> in <listcomp>(.0)
#       1 path = "C:/Users/SDS/Downloads/text.txt"
# ----> 2 recods = [json.loads(line) for line in open(path)]
#       3 recods[0]
#
# NameError: name 'json' is not defined

# %%
import json
path = "C:/Users/SDS/Downloads/text.txt"
recods = [json.loads(line) for line in open(path)]
print (recods[0])
# Out:
# {'al': 'vi-VN, en-US', 'll': [21.0333, 105.85], 'u': 'https://share.america.gov/everyday-conversations-writing-college-essay/', 'cy': 'Hanoi', 'hc': 1446564568, 'hh': '1.usa.gov', 'c': 'VN', 'nk': 0, 't': 1446872374, 'l': 'americanenglish', 'i': '', 'r': 'http://m.facebook.com/', 'g': '1M91fCv', '_id': '9f7472aa-05bd-15d1-bb10-17c839600b9f', 'k': '', 'gr': '44', 'a': 'Mozilla/5.0 (Linux; U; Android 4.3; vi-vn; SHV-E210K Build/JSS15J) AppleWebKit/534.30 (KHTML, like Gecko) Version/4.0 Mobile Safari/534.30 [FB_IAB/FB4A;FBAV/53.0.0.29.18;]', 'h': '1KW4Zp8', 'tz': 'Asia/Phnom_Penh'}

# %%
recodes[0]['tz']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-287cd89f52f3> in <module>()
# ----> 1 recodes[0]['tz']
#
# NameError: name 'recodes' is not defined

# %%
records[0]['tz']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-373459239710> in <module>()
# ----> 1 records[0]['tz']
#
# NameError: name 'records' is not defined

# %%
recodes[0]['tz']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-287cd89f52f3> in <module>()
# ----> 1 recodes[0]['tz']
#
# NameError: name 'recodes' is not defined

# %%
import json
path = "/Users/JYP/text.txt"
recods = [json.loads(line) for line in open(path)]
recods[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-a72877cad480> in <module>()
#       1 import json
#       2 path = "/Users/JYP/text.txt"
# ----> 3 recods = [json.loads(line) for line in open(path)]
#       4 recods[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/JYP/text.txt'

# %%
print (recods[0]['tz'])
# Out:
# Asia/Phnom_Penh

# %%
time_zones = [rec['tz'] for rec in recods]

# %%
print recods[0]['tz']
# Out:
#   File "<ipython-input-20-31eda1cc216d>", line 1
#     print recods[0]['tz']
#                ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4a69013be9f0> in <module>()
# ----> 1 python
#
# NameError: name 'python' is not defined

# %%
import json
path = "C:/Users/SDS/Downloads/text.txt"
recods = [json.loads(line) for line in open(path)]
recods[0]
time_zones = [rec['tz'] for rec in recods]

# %%
time_zones
# Out:
# ['Asia/Phnom_Penh',
#  'America/Chicago',
#  'America/New_York',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Los_Angeles',
#  'America/Chicago',
#  'America/New_York',
#  'Australia/Queensland',
#  'America/Denver',
#  'America/Chicago',
#  'America/New_York']

# %%
def get_counts(sequence):
    counts = {}
    
    for x in sequence:
        if x in counts:
            counts[x] +=1
        else:
            counts[x] = 1
    return counts

counts = get_counts(time_zones)
counts
# Out:
# {'America/Chicago': 3,
#  'America/Denver': 1,
#  'America/Los_Angeles': 3,
#  'America/New_York': 3,
#  'Asia/Phnom_Penh': 1,
#  'Australia/Queensland': 1}

# %%
time+_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-e1e4902b4a19> in <module>()
# ----> 1 get_ipython().magic('time +_')
#
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2305         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2306         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2307         return self.run_line_magic(magic_name, magic_arg_s)
#    2308
#    2309     #-------------------------------------------------------------------------
#
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2226                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2227             with self.builtin_trap:
# -> 2228                 result = fn(*args,**kwargs)
#    2229             return result
#    2230
#
# ...

# %%
len(time_zones)
# Out:
# 12

# %%
from collections import defaultdict
def get_counts2(sequence):
    counts = defaultdict(int) # values will initialize to 0
    for x in sequence:
        counts[x] += 1 
        return counts
counts = get_counts(time_zones)
counts
# Out:
# {'America/Chicago': 3,
#  'America/Denver': 1,
#  'America/Los_Angeles': 3,
#  'America/New_York': 3,
#  'Asia/Phnom_Penh': 1,
#  'Australia/Queensland': 1}

# %%
def top_counts(count_dict, n =10):
    value_key_pairs = [(count,tz) for tz , count in count_dict.items()]
    value_key_pairs.sort()
    return value_key_pairs[-n:]
top_counts(counts)
# Out:
# [(1, 'America/Denver'),
#  (1, 'Asia/Phnom_Penh'),
#  (1, 'Australia/Queensland'),
#  (3, 'America/Chicago'),
#  (3, 'America/Los_Angeles'),
#  (3, 'America/New_York')]

# %%
from collections import Counter
counts = Counter(time_zones)
counts.most_common(10)

# %%
from pandas import DataFrame , Series
import pandas as pd; import numpy as np
frame = DataFrame(recods)
frame
# Out:
#                                      _id  \
# 0   9f7472aa-05bd-15d1-bb10-17c839600b9f
# 1   7c2c683c-891d-c023-48c7-d42c046918e5
# 2   1d31f65a-e9bf-0943-2edb-2257ff63f955
# 3   6529ebcb-9963-d1eb-f2c3-fe45fb41feef
# 4   46a7119b-b52d-3cf8-7e58-70844001c064
# 5   239e8519-9ca4-3a00-b6a5-c48a0570770a
# 6   f3c69d82-b895-df17-39fb-eb7a328f8763
# 7   7ffd1451-11ad-e52d-6884-8663f2cd6896
# 8   522e0d39-8f11-1135-869b-d0c2480c3111
# 9   29963ad6-3b44-fc99-82e6-fb27cd66ac19
# 10  e666f96a-68f7-02f2-254e-397394ca98a5
# 11  4ec3a257-a41f-987e-2624-b11a883c68ee
#
#                                                     a              al   c  \
# 0   Mozilla/5.0 (Linux; U; Android 4.3; vi-vn; SHV...    vi-VN, en-US  VN
# 1   Mozilla/5.0 (iPhone; CPU iPhone OS 9_0_1 like ...           en-us  US
# 2        Twitter/6.39 CFNetwork/758.1.6 Darwin/15.0.0           en-us  US
# 3   Mozilla/5.0 (Windows NT 6.3; ARM; Trident/7.0;...  en-US,en;q=0.5  US
# ...

# %%
frame['tz'][:10]
# Out:
# 0         Asia/Phnom_Penh
# 1         America/Chicago
# 2        America/New_York
# 3     America/Los_Angeles
# 4     America/Los_Angeles
# 5     America/Los_Angeles
# 6         America/Chicago
# 7        America/New_York
# 8    Australia/Queensland
# 9          America/Denver
# Name: tz, dtype: object

# %%
tz_counts =  frame['tz'].value_counts()

# %%
tz_counts[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-cb01add4324f> in <module>()
# ----> 1 tz_counts[:10]
#
# NameError: name 'tz_counts' is not defined

# %%
clean_tz = frame['tz'].fillna('Missing')
clean_tz[clean_tz == ''] = 'Unknown'
tz_counts = clean_tz.value_counts()
tz_counts[:10]
# Out:
# America/Los_Angeles     3
# America/New_York        3
# America/Chicago         3
# Asia/Phnom_Penh         1
# America/Denver          1
# Australia/Queensland    1
# dtype: int64

# %%
tz_counts[:10].plot(kind='barh', rot =0)

# %%
results = Series([x.split()[0] for x in frame.a.dropna()])
results
# Out:
# 0      Mozilla/5.0
# 1      Mozilla/5.0
# 2     Twitter/6.39
# 3      Mozilla/5.0
# 4      Mozilla/5.0
# 5      Mozilla/5.0
# 6      Mozilla/5.0
# 7      Mozilla/5.0
# 8      Mozilla/5.0
# 9      Mozilla/5.0
# 10     Mozilla/5.0
# 11     Mozilla/5.0
# dtype: object

# %%
results.value_counts()[:2]
# Out:
# Mozilla/5.0     11
# Twitter/6.39     1
# dtype: int64

# %%
# %pylab
tz_counts[:10].plot(kind='barh', rot =0)
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab
tz_counts[:10].plot(kind='barh', rot =0).show()
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-509a75cb7784> in <module>()
#       1 get_ipython().magic('pylab')
# ----> 2 tz_counts[:10].plot(kind='barh', rot =0).show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
tz_counts[:10].show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-5cecb2296bed> in <module>()
# ----> 1 tz_counts[:10].show()
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'show'

# %%
# %pylab
tz_counts[:10].plot(kind='barh', rot =0)

# %%
import matplotlib.pyplot as p 
tz_counts[:10].plot(kind='barh', rot =0)

# %%
cframe =  frame[frame.a.notnull()]

# %%
operating_system = np.where(cframe['a'].str.contains('Windows'),'Windows','not Windows')
operating_system[:5]
# Out:
# array(['not Windows', 'not Windows', 'not Windows', 'Windows',
#        'not Windows'],
#       dtype='<U11')

# %%
operating_system = np.where(cframe['a'].str.contains('Windows'),'Windows','not 2222Windows')
operating_system[:5]

# %%
cframe['a']
# Out:
# 0     Mozilla/5.0 (Linux; U; Android 4.3; vi-vn; SHV...
# 1     Mozilla/5.0 (iPhone; CPU iPhone OS 9_0_1 like ...
# 2          Twitter/6.39 CFNetwork/758.1.6 Darwin/15.0.0
# 3     Mozilla/5.0 (Windows NT 6.3; ARM; Trident/7.0;...
# 4     Mozilla/5.0 (iPhone; CPU iPhone OS 9_0_2 like ...
# 5     Mozilla/5.0 (iPhone; CPU iPhone OS 9_1 like Ma...
# 6     Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...
# 7     Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 8     Mozilla/5.0 (Linux; U; Android 4.3; en-au; GT-...
# 9     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_5)...
# 10    Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...
# 11    Mozilla/5.0 (iPhone; CPU iPhone OS 9_1 like Ma...
# Name: a, dtype: object

# %%
by_tz_os = cframe.groupby(['tz',operating_system])
agg_counts = by_tz_os.size().unstack().fillna(0)
agg_counts[:10]
# Out:
#                       Windows  not Windows
# tz
# America/Chicago             1            2
# America/Denver              0            1
# America/Los_Angeles         1            2
# America/New_York            1            2
# Asia/Phnom_Penh             0            1
# Australia/Queensland        0            1

# %%
indexer = agg_counts.sum(1).argsort()
indexer[:10]
# Out:
# tz
# America/Chicago         1
# America/Denver          4
# America/Los_Angeles     5
# America/New_York        0
# Asia/Phnom_Penh         2
# Australia/Queensland    3
# dtype: int64

# %%
count_subset = agg_counts.take(indexer)[-10:]

# %%
count_subset
# Out:
#                       Windows  not Windows
# tz
# America/Denver              0            1
# Asia/Phnom_Penh             0            1
# Australia/Queensland        0            1
# America/Chicago             1            2
# America/Los_Angeles         1            2
# America/New_York            1            2

# %%
# %pylab
count_subset.plot(kind='barh',stacked = True)
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
count_subset.plot(kind='barh',stacked = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-e66f4841630b> in <module>()
# ----> 1 count_subset.plot(kind='barh',stacked = True)
#
# NameError: name 'count_subset' is not defined

# %%
normed_subset =  count_subset.div(count_subset.sum(1), axis = 0)

# %%
# %pylab
normed_subset.plot(kind = 'barh', stacked = True)
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
unames = ['user_id','gender','age','occupation','zip']
users = pd.read_table('C:/Users/SDS/Downloads/ml-1m/users.dat',sep='::',header =None,names=unames,engine='python')

rnames = ['user_id','movie_id','rating','timestamp']
ratings = pd.read_table('C:/Users/SDS/Downloads/ml-1m/ratings.dat',sep='::',header =None,names=rnames,engine='python')

mnames = ['movie_id','title','genders']
movies = pd.read_table('C:/Users/SDS/Downloads/ml-1m/movies.dat',sep='::',header =None,names=mnames,engine='python')

users[:5]
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
ratings[:5]
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies[:5]
# Out:
#    movie_id                               title                       genders
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings
# Out:
#          user_id  movie_id  rating  timestamp
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# 5              1      1197       3  978302268
# 6              1      1287       5  978302039
# 7              1      2804       5  978300719
# 8              1       594       4  978302268
# 9              1       919       4  978301368
# 10             1       595       5  978824268
# 11             1       938       4  978301752
# 12             1      2398       4  978302281
# 13             1      2918       4  978302124
# 14             1      1035       5  978301753
# 15             1      2791       4  978302188
# 16             1      2687       3  978824268
# 17             1      2018       4  978301777
# 18             1      3105       5  978301713
# ...

# %%
data  =  pd.merge(pd.merge(ratings,users),movies)
data
# Out:
#          user_id  movie_id  rating   timestamp gender  age  occupation    zip  \
# 0              1      1193       5   978300760      F    1          10  48067
# 1              2      1193       5   978298413      M   56          16  70072
# 2             12      1193       4   978220179      M   25          12  32793
# 3             15      1193       4   978199279      M   25           7  22903
# 4             17      1193       5   978158471      M   50           1  95350
# 5             18      1193       4   978156168      F   18           3  95825
# 6             19      1193       5   982730936      M    1          10  48073
# 7             24      1193       5   978136709      F   25           7  10023
# 8             28      1193       3   978125194      F   25           1  14607
# 9             33      1193       5   978557765      M   45           3  55421
# 10            39      1193       5   978043535      M   18           4  61820
# ...

# %%
data.ix[0]
# Out:
# user_id                                            1
# movie_id                                        1193
# rating                                             5
# timestamp                                  978300760
# gender                                             F
# age                                                1
# occupation                                        10
# zip                                            48067
# title         One Flew Over the Cuckoo's Nest (1975)
# genders                                        Drama
# Name: 0, dtype: object

# %%
mean_ratings = data.pivot_table('rating', index ='title', columns = 'gender',aggfunc='mean')
mean_ratings[:5]
# Out:
# gender                                F         M
# title
# $1,000,000 Duck (1971)         3.375000  2.761905
# 'Night Mother (1986)           3.388889  3.352941
# 'Til There Was You (1997)      2.675676  2.733333
# 'burbs, The (1989)             2.793478  2.962085
# ...And Justice for All (1979)  3.828571  3.689024

# %%
ratings_by_title = data.groupby('title').size()
ratings_by_title[:10]
# Out:
# title
# $1,000,000 Duck (1971)                37
# 'Night Mother (1986)                  70
# 'Til There Was You (1997)             52
# 'burbs, The (1989)                   303
# ...And Justice for All (1979)        199
# 1-900 (1994)                           2
# 10 Things I Hate About You (1999)    700
# 101 Dalmatians (1961)                565
# 101 Dalmatians (1996)                364
# 12 Angry Men (1957)                  616
# dtype: int64

# %%
active_titles = ratings_by_title.index[ratings_by_title>=250]
active_titles
# Out:
# Index([''burbs, The (1989)', '10 Things I Hate About You (1999)',
#        '101 Dalmatians (1961)', '101 Dalmatians (1996)', '12 Angry Men (1957)',
#        '13th Warrior, The (1999)', '2 Days in the Valley (1996)',
#        '20,000 Leagues Under the Sea (1954)', '2001: A Space Odyssey (1968)',
#        '2010 (1984)',
#        ...
#        'X-Men (2000)', 'Year of Living Dangerously (1982)',
#        'Yellow Submarine (1968)', 'You've Got Mail (1998)',
#        'Young Frankenstein (1974)', 'Young Guns (1988)',
#        'Young Guns II (1990)', 'Young Sherlock Holmes (1985)',
#        'Zero Effect (1998)', 'eXistenZ (1999)'],
#       dtype='object', name='title', length=1216)

# %%
mean_ratings = mean_ratings.ix[active_titles]
mean_ratings
# Out:
# gender                                                     F         M
# title
# 'burbs, The (1989)                                  2.793478  2.962085
# 10 Things I Hate About You (1999)                   3.646552  3.311966
# 101 Dalmatians (1961)                               3.791444  3.500000
# 101 Dalmatians (1996)                               3.240000  2.911215
# 12 Angry Men (1957)                                 4.184397  4.328421
# 13th Warrior, The (1999)                            3.112000  3.168000
# 2 Days in the Valley (1996)                         3.488889  3.244813
# 20,000 Leagues Under the Sea (1954)                 3.670103  3.709205
# 2001: A Space Odyssey (1968)                        3.825581  4.129738
# 2010 (1984)                                         3.446809  3.413712
# 28 Days (2000)                                      3.209424  2.977707
# 39 Steps, The (1935)                                3.965517  4.107692
# ...

# %%
top_female_ratings = mean_ratings.sort_index(by = 'F' ,  ascending=False)
top_female_ratings[:10]
# Out:
# gender                                                     F         M
# title
# Close Shave, A (1995)                               4.644444  4.473795
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       4.572650  4.464589
# Wallace & Gromit: The Best of Aardman Animation...  4.563107  4.385075
# Schindler's List (1993)                             4.562602  4.491415
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Grand Day Out, A (1992)                             4.537879  4.293255
# To Kill a Mockingbird (1962)                        4.536667  4.372611
# Creature Comforts (1990)                            4.513889  4.272277
# Usual Suspects, The (1995)                          4.513317  4.518248

# %%
mean_ratings['diff'] = mean_ratings['M'] - mean_ratings['F']
sorted_by_diff = mean_ratings.sort_index(by='diff')
sorted_by_diff[:15]
# Out:
# gender                                        F         M      diff
# title
# Dirty Dancing (1987)                   3.790378  2.959596 -0.830782
# Jumpin' Jack Flash (1986)              3.254717  2.578358 -0.676359
# Grease (1978)                          3.975265  3.367041 -0.608224
# Little Women (1994)                    3.870588  3.321739 -0.548849
# Steel Magnolias (1989)                 3.901734  3.365957 -0.535777
# Anastasia (1997)                       3.800000  3.281609 -0.518391
# Rocky Horror Picture Show, The (1975)  3.673016  3.160131 -0.512885
# Color Purple, The (1985)               4.158192  3.659341 -0.498851
# Age of Innocence, The (1993)           3.827068  3.339506 -0.487561
# Free Willy (1993)                      2.921348  2.438776 -0.482573
# French Kiss (1995)                     3.535714  3.056962 -0.478752
# Little Shop of Horrors, The (1960)     3.650000  3.179688 -0.470312
# Guys and Dolls (1955)                  4.051724  3.583333 -0.468391
# ...

# %%
sorted_by_diff[::-1][:15]
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704
# Porky's (1981)                          2.296875  2.836364  0.539489
# Animal House (1978)                     3.628906  4.167192  0.538286
# ...

# %%
 rating_std_by_title = data.groupby('title')['rating'].std()
rating_std_title = rating_std_by_title.ix[active_titles]
rating_std_by_title.order(ascending=False)[:10]
# Out:
# title
# Foreign Student (1994)                                             2.828427
# Criminal Lovers (Les Amants Criminels) (1999)                      2.309401
# Identification of a Woman (Identificazione di una donna) (1982)    2.121320
# Sunset Park (1996)                                                 2.121320
# Eaten Alive (1976)                                                 2.121320
# Neon Bible, The (1995)                                             2.121320
# Talk of Angels (1998)                                              2.121320
# Tokyo Fist (1995)                                                  2.121320
# Paralyzing Fear: The Story of Polio in America, A (1998)           2.121320
# Better Living (1998)                                               2.121320
# Name: rating, dtype: float64

# %%
names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-763921f80799> in <module>()
# ----> 1 names
#
# NameError: name 'names' is not defined

# %%
import pandas as pd
names1880 = pd.read_csv('C:/Users/SDS/Downloads/names/yob1880.txt',names=['name','sex','births'])
names1880
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# 5      Margaret   F    1578
# 6           Ida   F    1472
# 7         Alice   F    1414
# 8        Bertha   F    1320
# 9         Sarah   F    1288
# 10        Annie   F    1258
# 11        Clara   F    1226
# 12         Ella   F    1156
# 13     Florence   F    1063
# 14         Cora   F    1045
# 15       Martha   F    1040
# 16        Laura   F    1012
# 17       Nellie   F     995
# 18        Grace   F     982
# 19       Carrie   F     949
# 20        Maude   F     858
# 21        Mabel   F     808
# 22       Bessie   F     796
# 23       Jennie   F     793
# 24     Gertrude   F     787
# 25        Julia   F     783
# 26       Hattie   F     769
# 27        Edith   F     768
# 28       Mattie   F     704
# 29         Rose   F     700
# ...         ...  ..     ...
# 1970      Philo   M       5
# ...

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110491
# Name: births, dtype: int64

# %%
years = range(1880,2011)
pieces = []
columns = ['name','sex' ,'birth']

for year in years:
    path = 'C:/Users/SDS/Downloads/names/yob%d.txt' % year
    frame = pd.read_csv(path,names = columns)
    
    frame['year'] = year
    pieces.append(frame)
    
# Concatenate everything into a single DataFrame
names = pd.concat(pieces,ignore_index=True)

names
# Out:
#               name sex  birth  year
# 0             Mary   F   7065  1880
# 1             Anna   F   2604  1880
# 2             Emma   F   2003  1880
# 3        Elizabeth   F   1939  1880
# 4           Minnie   F   1746  1880
# 5         Margaret   F   1578  1880
# 6              Ida   F   1472  1880
# 7            Alice   F   1414  1880
# 8           Bertha   F   1320  1880
# 9            Sarah   F   1288  1880
# 10           Annie   F   1258  1880
# 11           Clara   F   1226  1880
# 12            Ella   F   1156  1880
# 13        Florence   F   1063  1880
# 14            Cora   F   1045  1880
# 15          Martha   F   1040  1880
# 16           Laura   F   1012  1880
# 17          Nellie   F    995  1880
# 18           Grace   F    982  1880
# 19          Carrie   F    949  1880
# 20           Maude   F    858  1880
# 21           Mabel   F    808  1880
# 22          Bessie   F    796  1880
# 23          Jennie   F    793  1880
# 24        Gertrude   F    787  1880
# ...

# %%
total_births =  names.pivot_table('birth', index = 'year', columns = 'sex', aggfunc = sum)
total_births.tail()
total_births.plot(title='Total births by sex and year')

# %%
def add_prop(group):
    # Integer division floors
    births = group.birth.astype(float)
    
    group['prop'] = births / births.sum()
    return group
names = names.groupby(['year','sex']).apply(add_prop)

# %%
names
# Out:
#               name sex  birth  year      prop
# 0             Mary   F   7065  1880  0.077643
# 1             Anna   F   2604  1880  0.028618
# 2             Emma   F   2003  1880  0.022013
# 3        Elizabeth   F   1939  1880  0.021309
# 4           Minnie   F   1746  1880  0.019188
# 5         Margaret   F   1578  1880  0.017342
# 6              Ida   F   1472  1880  0.016177
# 7            Alice   F   1414  1880  0.015540
# 8           Bertha   F   1320  1880  0.014507
# 9            Sarah   F   1288  1880  0.014155
# 10           Annie   F   1258  1880  0.013825
# 11           Clara   F   1226  1880  0.013474
# 12            Ella   F   1156  1880  0.012704
# 13        Florence   F   1063  1880  0.011682
# 14            Cora   F   1045  1880  0.011484
# 15          Martha   F   1040  1880  0.011429
# 16           Laura   F   1012  1880  0.011122
# 17          Nellie   F    995  1880  0.010935
# 18           Grace   F    982  1880  0.010792
# ...

# %%
import numpy as np
np.allclose(names.groupby(['year','sex']).prop.sum(),1)
# Out:
# True

# %%
def get_top1000(group):
    return group.sort_index(by='birth',ascending =False)[:1000]

grouped = names.groupby(['year','sex'])
top1000 = grouped.apply(get_top1000)

# %%
top1000
# Out:
#                        name sex  birth  year      prop
# year sex
# 1880 F   0             Mary   F   7065  1880  0.077643
#          1             Anna   F   2604  1880  0.028618
#          2             Emma   F   2003  1880  0.022013
#          3        Elizabeth   F   1939  1880  0.021309
#          4           Minnie   F   1746  1880  0.019188
#          5         Margaret   F   1578  1880  0.017342
#          6              Ida   F   1472  1880  0.016177
#          7            Alice   F   1414  1880  0.015540
#          8           Bertha   F   1320  1880  0.014507
#          9            Sarah   F   1288  1880  0.014155
#          10           Annie   F   1258  1880  0.013825
#          11           Clara   F   1226  1880  0.013474
#          12            Ella   F   1156  1880  0.012704
#          13        Florence   F   1063  1880  0.011682
#          14            Cora   F   1045  1880  0.011484
#          15          Martha   F   1040  1880  0.011429
# ...

# %%
pieces = []
for year,group in names.groupby(['year','sex']):
    pieces.append(group.sort_index(by='birth',ascending=False)[:1000])
top1000 = pd.concat(pieces,ignore_index=True)

# %%
top1000
# Out:
#              name sex  birth  year      prop
# 0            Mary   F   7065  1880  0.077643
# 1            Anna   F   2604  1880  0.028618
# 2            Emma   F   2003  1880  0.022013
# 3       Elizabeth   F   1939  1880  0.021309
# 4          Minnie   F   1746  1880  0.019188
# 5        Margaret   F   1578  1880  0.017342
# 6             Ida   F   1472  1880  0.016177
# 7           Alice   F   1414  1880  0.015540
# 8          Bertha   F   1320  1880  0.014507
# 9           Sarah   F   1288  1880  0.014155
# 10          Annie   F   1258  1880  0.013825
# 11          Clara   F   1226  1880  0.013474
# 12           Ella   F   1156  1880  0.012704
# 13       Florence   F   1063  1880  0.011682
# 14           Cora   F   1045  1880  0.011484
# 15         Martha   F   1040  1880  0.011429
# 16          Laura   F   1012  1880  0.011122
# 17         Nellie   F    995  1880  0.010935
# 18          Grace   F    982  1880  0.010792
# 19         Carrie   F    949  1880  0.010429
# ...

# %%
boys = top1000[top1000.sex == 'M']
girls = top1000[top1000.sex == 'F']
total_births = top1000.pivot_table('birth',index = 'year',columns='name' , aggfunc =sum)
total_births
# Out:
# name  Aaden  Aaliyah  Aarav  Aaron  Aarush  Ab  Abagail  Abb  Abbey  Abbie  \
# year
# 1880    NaN      NaN    NaN    102     NaN NaN      NaN  NaN    NaN     71
# 1881    NaN      NaN    NaN     94     NaN NaN      NaN  NaN    NaN     81
# 1882    NaN      NaN    NaN     85     NaN NaN      NaN  NaN    NaN     80
# 1883    NaN      NaN    NaN    105     NaN NaN      NaN  NaN    NaN     79
# 1884    NaN      NaN    NaN     97     NaN NaN      NaN  NaN    NaN     98
# 1885    NaN      NaN    NaN     88     NaN   6      NaN  NaN    NaN     88
# 1886    NaN      NaN    NaN     86     NaN NaN      NaN  NaN    NaN     84
# 1887    NaN      NaN    NaN     78     NaN NaN      NaN  NaN    NaN    104
# 1888    NaN      NaN    NaN     90     NaN NaN      NaN  NaN    NaN    137
# 1889    NaN      NaN    NaN     85     NaN NaN      NaN  NaN    NaN    107
# 1890    NaN      NaN    NaN     96     NaN NaN      NaN    6    NaN    140
# ...

# %%
subset = total_births[['John','Harry','Mary','Marilyn']]
subset.plot(subplots = True , figsize =(12,10), grid =False , title = 'Number of births per Year')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0F043B50>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0F0AF230>], dtype=object)

# %%
table = top1000.pivot_table('prop',index ='year', columns = 'sex' , aggfunc = sum )
table.plot(title='Sum of table1000.prop by year and sex', yticks = np.linspace(0,1.2,13) ,xticks = range(1880,2020,10))

# %%
df = boys[boys.year == 2010]
df
# Out:
#                name sex  birth  year      prop
# 260877        Jacob   M  22082  2010  0.011538
# 260878        Ethan   M  17985  2010  0.009397
# 260879      Michael   M  17308  2010  0.009044
# 260880       Jayden   M  17152  2010  0.008962
# 260881      William   M  17030  2010  0.008898
# 260882    Alexander   M  16742  2010  0.008748
# 260883         Noah   M  16428  2010  0.008584
# 260884       Daniel   M  15815  2010  0.008263
# 260885        Aiden   M  15516  2010  0.008107
# 260886      Anthony   M  15470  2010  0.008083
# 260887       Joshua   M  15410  2010  0.008052
# 260888        Mason   M  14831  2010  0.007749
# 260889  Christopher   M  14243  2010  0.007442
# 260890       Andrew   M  14221  2010  0.007431
# 260891        David   M  14171  2010  0.007404
# 260892      Matthew   M  14099  2010  0.007367
# 260893        Logan   M  14012  2010  0.007321
# 260894       Elijah   M  13867  2010  0.007246
# 260895        James   M  13852  2010  0.007238
# ...

# %%
prop_cumsum = df.sort_index(by = 'prop', ascending =False).prop.cumsum()
prop_cumsum[:10]
# Out:
# 260877    0.011538
# 260878    0.020935
# 260879    0.029979
# 260880    0.038941
# 260881    0.047839
# 260882    0.056587
# 260883    0.065171
# 260884    0.073434
# 260885    0.081541
# 260886    0.089625
# Name: prop, dtype: float64

# %%
prop_cumsum.searchsorted(0.5)
# Out:
# array([116], dtype=int32)

# %%
df = boys[boys.year == 1900]
in1900 = df.sort_index(by = 'prop',ascending =False).prop.cumsum()
in1900.searchsorted(0.5) +1
# Out:
# array([25], dtype=int32)

# %%
def get_quantitle_count(group,q=0.5):
    group = group.sort_index(by='prop',ascending=False)
    return group.prop.cumsum().searchsorted(q)+1

diversity = top1000.groupby(['year','sex']).apply(get_quantitle_count)
diversity = diversity.unstack('sex')
diversity.head()
# Out:
# sex      F     M
# year
# 1880  [38]  [14]
# 1881  [38]  [14]
# 1882  [38]  [15]
# 1883  [39]  [15]
# 1884  [39]  [16]

# %%
diversity=diversity.astype(float)
diversity.plot(title="Number of popular irthname in top 50%")

# %%
get_last_letter = lambda x : x[-1]
    last_letters = names.name.map(get_last_letter)
    last_letters.name = 'last_letter'
    
    table = names.pivot_table('birth',index=last_letters,columns=['sex','year'],aggfunc = sum)
# Out:
#   File "<ipython-input-97-9cb45e50e09f>", line 2
#     last_letters = names.name.map(get_last_letter)
#     ^
# IndentationError: unexpected indent
